# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Mar 19 08:11:42 2021

# %%
@author: m

# %%
Ch2 p15

# %%
Using Gaussian elimination with partial pivoting and back-substitution

# %%
a. Solve the equations of exercise 10
b. Using part (a), find the determinant of the coefficient matrix
c. What is the LU decomposition of the coefficient matrix ?

# %% [markdown]
# <br>
# import numpy as np<br>
# from naf.linalg import gega, gesv<br>
# from naf.linalg import det<br>
# a = np.array([[1,1,-2],<br>
#               [4,-2,1],<br>
#               [3,-1,3]], dtype=float)<br>
# b = np.array([3,5,8], dtype=float)<br>
# lu, ov = gega(a)<br>
# print(lu, ov)<br>
# print(gesv(lu, ov, b))<br>
# print(det(a))
