# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 19 07:30:00 2021

# %%
@author: m

# %%
Ch2 p26

# %%
Solve this tri-diagonal system
...
by the special algorithm that stores the augument matrix
in a 5x4 array.

# %% [markdown]
# <br>
# import numpy as np<br>
# from naf.linalg import tddo, tdsv<br>
# import pdb<br>
# a = np.array([[0, 4, -1],<br>
#               [-1, 4, -1],<br>
#               [-1, 4, -1],<br>
#               [-1, 4, -1],<br>
#               [-1, 4, 0]], dtype=float)<br>
# b = np.transpose(np.array([100, 200, 200, 200, 100], dtype=float))<br>
# lu = tddo(a)<br>
# x = tdsv(lu, b)<br>
# print(x)
