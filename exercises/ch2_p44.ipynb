# %% [markdown]
# <br>
# Ch2 p44<br>
# Suppose, in exercise 42, that uncertainties of measurement<br>
# give slight changes in some of the element of A. Specifically,<br>
# suppose a_11 is 3.00 instead of 3.01, and a_31 is 0.99 instead<br>
# of 0.987. What change does this cause in the solution vector<br>
# using precise arithmetic).<br>

# %%
import numpy as np
from naf.linalg import gedo, dosv
from naf.linalg_exp import gedo as gedo_e
from naf.linalg_exp import dosv as dosv_e
from naf.linalg_exp import invr
import naf.linalg_exp

# %%
np.set_printoptions(precision=10, threshold=10, suppress=True)
naf.linalg_exp.set_options(precision=10)

# %%
a42 = np.array([[3.01,6.03,1.99,],
              [1.27,4.16,-1.23],
              [0.987,-4.81,9.34]], dtype=float)

# %%
a44 = np.array([[3.00,6.03,1.99,],
              [1.27,4.16,-1.23],
              [0.99,-4.81,9.34]], dtype=float)

# %%
b = np.array([1,1,1], dtype=float)

# %%
lu42, ov42 = gedo(a42)

# %%
print(lu42, ov42)

# %%
x42 = dosv(lu42, ov42, b)

# %%
print(x42)

# %%
lu44, ov44 = gedo(a44)

# %%
print(lu44, ov44)

# %%
x44 = dosv(lu44, ov44, b)

# %%
print(x44)
