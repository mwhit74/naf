# %% [markdown]
# <br>
# Ch2 p29<br>
# a. Matrix A in exercise 27 is singular. Do its rows for linearly<br>
# independent vectors? Find the values for the a_i in Eq. (2.24).<br>
# b. Repeat part (a) for the elements of A condsidered as column<br>
# vectors.<br>
# Notes:<br>
# Actually learned how to solve the problem with the example from <br>
# Uni. of Oregon. Tested the method with the example from the <br>
# textbook. Finally, solved the original problem with the same<br>
# method. See notebook for additional steps in the solution<br>
# process. <br>

# %%
import sys
import numpy as np
from naf.linalg import gedo, dosv
import pdb

# %%
a = np.array([[-2, 3, -2],
              [1, -4, 7],
              [-1, -6, 17]], dtype=float)

# %%
at = np.transpose(a)

# %% [markdown]
# xample matrix from Section 2.9 in text book

# %%
a2 = np.array([[1, -2, 3],
               [2, 4, -1],
               [-1, -14, 11]], dtype=float)

# %%
a3 = np.transpose(a2)

# %% [markdown]
# xample matrix from University of Oregon

# %%
a4 = np.array([[2, 3, 5],
               [-1, -4, -10],
               [1, -2, -8]], dtype=float)

# %% [markdown]
# a. LU decomposition of matrix A to determine a_i values<br>
#  the rows

# %%
lu1, ov1 = gedo(a, False)

# %%
print(lu1, ov1)

# %% [markdown]
# b. LU decomposition of matrix A to determine a_i values<br>
#  the rows

# %%
lu2, ov2 = gedo(at, False)

# %%
print(lu2, ov2)

# %% [markdown]
# Testing example matrix from text book to check technique<br>
# arned from Uni. of Oregon website

# %% [markdown]
# ows

# %%
lu3, ov3 = gedo(a3, False)

# %%
print(lu3, ov3)

# %% [markdown]
# olumns

# %%
lu4, ov4 = gedo(a4, False)

# %%
print(lu4, ov4)

# %% [markdown]
# Testing example matrix from University of Oregon. Example<br>
# explains how to use the elimination matrix to find the vector<br>
#  a_i's for a singular matrix

# %%
lu5, ov5 = gedo(a5, False)

# %%
print(lu5, ov5)
